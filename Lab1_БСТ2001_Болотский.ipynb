# %% [markdown]
# # Лабораторная работа №1
#
# ## Выполнил студент группы БСТ2001 Болотский К.С.
#
# ### Задание №1
#
# 1.	Создать Jupyter Notebook со следующим наименованием: Lab1_Группа_ФИО
# 2.	Создать новую ячейку с помощью кнопки
# 3.	В созданной ячейке по указанной ниже форме заполните оглавление файла, заменив наименование группы и вписав свое ФИО,
# 4.	С помощью кнопки   запустите выполнение всех ячеек.
# 5.	После выполнения у вас должна отформатироваться ячейка с оглавлением и должен выполниться “Hello, World!” (см. рис. 2).

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
#
# Написать генератор случайных матриц(многомерных), который принимает опциональные параметры m, n, min_limit, max_limit, где m и n указывают размер матрицы, а min_lim и max_lim - минимальное и максимальное значение для генерируемого числа . По умолчанию при отсутствии параметров принимать следующие значения:
# m = 50
# n = 50
# min_limit = -250
# max_limit = 1000 + (номер своего варианта)
#
# ### Задание №3
#
# Реализовать методы сортировки строк числовой матрицы в соответствии с заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со временем стандартной функции сортировки. Испытания проводить на сгенерированных матрицах.
# Методы:
# -Выбором
# -Вставкой
# -Обменом
# -Шелла
# -Турнирная
# -Быстрая сортировка
# -Пирамидальная
#
# ### Задание №4
# Создать публичный репозиторий на github, и запушить выполненное задание в .ipynb формате.

# %%
import math
import random
import time

m = input('m = ')
n = input('n = ')
m = int(m)
n = int(n)
if m <= 0:
    m = 50
if n <= 0:
    n = 50

min_limit = input('min_limit = ')
max_limit = input('max_limit = ')
min_limit = int(min_limit)
max_limit = int(max_limit)
if min_limit == 0:
    min_limit = -250
if max_limit == 0:
    max_limit = 1000+6
if min_limit > max_limit:
    min_limit = -250
    max_limit = 1000 + 6

Matrix = [[random.randint(min_limit, max_limit) for j in range(n)] for i in range(m)]
print('Matrix:')
Matrix1=Matrix2=Matrix3=Matrix4=Matrix5=Matrix6=Matrix7=Matrix
for i in range(m):
    print(Matrix[i])
# Out:
# m = 0
# n = 0
# min_limit = 0
# max_limit = 0
# Matrix:
# [-39, 606, 415, 257, 654, 336, 923, 871, 177, 803, 337, 115, 499, 743, 709, -235, 236, 833, 151, 768, -58, 197, -50, 36, 708, 415, -89, 223, 988, 238, 590, -38, 907, -191, 130, 104, 931, 22, 104, -92, 213, 125, 704, 769, 776, 207, 870, 642, 935, 240]
# [816, 604, 742, 946, 230, 881, 699, -166, 66, 924, 993, 749, 914, 1003, 702, 470, 333, 272, 553, 968, 685, 129, 185, 48, 437, 39, 16, 55, 461, 233, 839, 606, -85, 219, -39, 494, 338, 444, -190, -69, 103, 681, 909, 206, -143, 55, 292, -43, 907, -205]
# [781, 137, 404, -147, -102, -22, 242, 915, 463, -122, 450, 712, -151, 785, -36, 435, 439, 752, 66, -75, 160, 410, 908, 567, 435, 80, 672, 979, -115, 619, 95, 479, 846, 573, 226, 758, 796, -164, 342, -108, 201, 70, -198, 499, 668, -134, 420, 656, 620, 116]
# ...

# %%
# Сортировка выбором
def selection_sort(array):
    for i in range(len(array)):
        low_index = i
        for j in range(i + 1, len(array)):
            if array[j] < array[low_index]:
                low_index = j
        array[i], array[low_index] = array[low_index], array[i]

print('')
print('Viborka:')
start = time.perf_counter()
for i in range(m):
    selection_sort(Matrix1[i])
    print(Matrix1[i])
print(f'Прошло: {time.perf_counter() - start}')
# Out:
# Viborka:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935, 988]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993, 1003]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915, 979]
# ...

# %%
# Сортировка вставкой
def insertionSort(array):
    for i in range(1, len(array)):
        key = array[i]
        j = i-1
        while array[j] > key and j >= 0:
            array[j+1] = array[j]
            j -= 1
        array[j+1] = key
    return array

print('')
print('Vstavka:')
start1 = time.perf_counter()
for i in range(m):
    insertionSort(Matrix2[i])
    print(Matrix2[i])
print(f'Прошло: {time.perf_counter() - start1}')
# Out:
# Vstavka:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935, 988]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993, 1003]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915, 979]
# ...

# %%
# Сортировка обменом(пузырьковая)
def bubbleSort(array):
    swapped = False
    for i in range(len(array)-1,0,-1):
        for j in range(i):
            if array[j]>array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
                swapped= True
        if swapped:
            swapped=False
        else:
            break
    return array

print('')
print('Obmen:')
start2 = time.perf_counter()
for i in range(m):
    bubbleSort(Matrix3[i])
    print(Matrix3[i])
print(f'Прошло: {time.perf_counter() - start2}')
# Out:
# Obmen:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935, 988]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993, 1003]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915, 979]
# ...

# %%
# Сортировка Шелла
def shellSort(array):
    n = len(array)
    k = int(math.log2(n))
    interval = 2**k -1
    while interval > 0:
        for i in range(interval, n):
            temp = array[i]
            j = i
            while j >= interval and array[j - interval] > temp:
                array[j] = array[j - interval]
                j -= interval
            array[j] = temp
        k -= 1
        interval = 2**k -1
    return array

print('')
print('Shella:')
start3 = time.perf_counter()
for i in range(m):
    shellSort(Matrix4[i])
    print(Matrix4[i])
print(f'Прошло: {time.perf_counter() - start3}')
# Out:
# Shella:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935, 988]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993, 1003]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915, 979]
# ...

# %%
# Быстрая сортировка
def quickSort(array):
    if len(array)> 1:
        pivot=array.pop()
        grtr_lst, equal_lst, smlr_lst = [], [pivot], []
        for item in array:
            if item == pivot:
                equal_lst.append(item)
            elif item > pivot:
                grtr_lst.append(item)
            else:
                smlr_lst.append(item)
        return (quickSort(smlr_lst) + equal_lst + quickSort(grtr_lst))
    else:
        return array
print('')
print('Fast Quick:')
start5 = time.perf_counter()
for i in range(m):
    quickSort(Matrix6[i])
    print(Matrix6[i])
print(f'Прошло: {time.perf_counter() - start5}')
# Out:
# Fast Quick:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915]
# ...

# %%
# Турнирная(слияние)
def mergeSort(nums):
    if len(nums)==1:
        return nums
    mid = (len(nums)-1) // 2
    lst1 = mergeSort(nums[:mid+1])
    lst2 = mergeSort(nums[mid+1:])
    result = merge(lst1, lst2)
    return result
def merge(lst1, lst2):
    lst = []
    i = 0
    j = 0
    while(i<=len(lst1)-1 and j<=len(lst2)-1):
        if lst1[i]<lst2[j]:
            lst.append(lst1[i])
            i+=1
        else:
            lst.append(lst2[j])
            j+=1
    if i>len(lst1)-1:
        while(j<=len(lst2)-1):
            lst.append(lst2[j])
            j+=1
    else:
        while(i<=len(lst1)-1):
            lst.append(lst1[i])
            i+=1
    return lst
print('')
print('Tyrnir?But Слияние:')
start4 = time.perf_counter()
for i in range(m):
    mergeSort(Matrix5[i])
    print(Matrix5[i])
print(f'Прошло: {time.perf_counter() - start4}')
# Out:
# Tyrnir?But Слияние:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915]
# ...

# %%
# Пирамидная
def heapify(array, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2

    if l < n and array[i] < array[l]:
        largest = l
    if r < n and array[largest] < array[r]:
        largest = r

    if largest != i:
        array[i], array[largest] = array[largest], array[i]
        heapify(array, n, largest)
def heapSort(array):
    n = len(array)
    for i in range(n // 2, -1, -1):
        heapify(array, n, i)
    for i in range(n - 1, 0, -1):
        array[i], array[0] = array[0], array[i]
        heapify(array, i, 0)
    return array
print('')
print('Piramida:')
start6 = time.perf_counter()
for i in range(m):
    heapSort(Matrix7[i])
    print(Matrix7[i])
print(f'Прошло: {time.perf_counter() - start6}')
# Out:
# Piramida:
# [-235, -191, -92, -89, -58, -50, -39, -38, 22, 36, 104, 104, 115, 125, 130, 151, 177, 197, 207, 213, 223, 236, 238, 240, 257, 336, 337, 415, 415, 499, 590, 606, 642, 654, 704, 708, 709, 743, 768, 769, 776, 803, 833, 870, 871, 907, 923, 931, 935]
# [-205, -190, -166, -143, -85, -69, -43, -39, 16, 39, 48, 55, 55, 66, 103, 129, 185, 206, 219, 230, 233, 272, 292, 333, 338, 437, 444, 461, 470, 494, 553, 604, 606, 681, 685, 699, 702, 742, 749, 816, 839, 881, 907, 909, 914, 924, 946, 968, 993]
# [-198, -164, -151, -147, -134, -122, -115, -108, -102, -75, -36, -22, 66, 70, 80, 95, 116, 137, 160, 201, 226, 242, 342, 404, 410, 420, 435, 435, 439, 450, 463, 479, 499, 567, 573, 619, 620, 656, 668, 672, 712, 752, 758, 781, 785, 796, 846, 908, 915]
# ...
